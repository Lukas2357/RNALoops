# %%
from rnaloops.data_explorer.import_helper import *
df = get_prepared_df()
# Out:
# imported pandas, numpy, seaborn, matplotlib and all functions from data_explorer/explore_fcts.py

# %%
home_grouped = df.groupby('home_structure').count().sort_values(by='loop_type')
indices = home_grouped[home_grouped.loop_type == 5].index.values
bsp = df[df.home_structure.isin(indices)].sort_values(by='home_structure')[25:30]

# %%
show_structure(indices=bsp.index.values, web=True)
# Out:
# Structure web url: https://rnaloops.cs.put.poznan.pl/search/details/87630
# Structure web url: https://rnaloops.cs.put.poznan.pl/search/details/87627
# Structure web url: https://rnaloops.cs.put.poznan.pl/search/details/87629
# Structure web url: https://rnaloops.cs.put.poznan.pl/search/details/87628
# Structure web url: https://rnaloops.cs.put.poznan.pl/search/details/87631
#       loop_type home_structure  \
# 87630    03-way           3ok4
# 87627    03-way           3ok4
# 87629    03-way           3ok4
# 87628    03-way           3ok4
# 87631    03-way           3ok4
#
#                                              db_notation  \
# 87630                                       ([ — {) — ]}
# 87627                                       {[ — (} — ])
# 87629                                       {( — [} — )]
# 87628  (((((( — ))))....................((((( — )))))...
# 87631                                       ([ — {) — ]}
#
# ...

# %%
df.groupby('whole_sequence').count().sort_values(by='loop_type', ascending=False)
# Out:
#                                                     loop_type  home_structure  \
# whole_sequence
# CG — UAAAG — CUAA — CG — CG                               708             708
# GAAAC — CAUC — CGG — GCGAG                                629             629
# GCGGUGGAGCAUGUG — CACGUGCUAC — GGAAUCGC                   609             609
# CG — CCAAC — CAG — CG — GG                                486             486
# GCUCGUGCC — GGUGUUGGG — CCCGCAACGAGC                      484             484
# ...                                                       ...             ...
# AUCCGACUGU — ACAAAGCAUUGU — ACAAUGUGAUUUCUGC — ...          0               0
# AUGCCUGAAUAG — CGUAGCG — CGUCGAAUUUGGGUAU                   0               0
# GAUUUAAG — CCAUUUAC — CC — GAG — GUGCCAG — GC —...          0               0
# AUGCUUGU — AAAUAACA — UGGAAUG — CAAUUGGA — UCCA...          0               0
# GGUUCCCUC — GAGU — GCAuAAGGGAGCU                            0               0
#
# ...

# %%
test = df.way5[df.way5.whole_sequence == 'CG — UAAAG — CUAA — CG — CG']

# %%
set_attrs(test)

# %%
_ = test.euler.hist(figsize=(12, 12), grid=False, bins=100)

# %%
test
# Out:
#        loop_type home_structure                  db_notation  \
# 125959    05-way           4u1v  ([ — [...( — (..] — ]) — ))
# 94332     05-way           5czp  ([ — [...( — (..] — ]) — ))
# 157058    05-way           6xhy  ([ — [...( — (..] — ]) — ))
# 145073    05-way           6oxa  ([ — [...( — (..] — ]) — ))
# 96040     05-way           4lfz  ([ — [...( — (..] — ]) — ))
# ...          ...            ...                          ...
# 144556    05-way           6ha1  ([ — [...( — (..] — ]) — ))
# 102864    05-way           4wzd  ([ — [...( — (..] — ]) — ))
# 111038    05-way           4wqy  ([ — [...( — (..] — ]) — ))
# 116371    05-way           5lmq  ([ — [...( — (..] — ]) — ))
# 111185    05-way           5j5b  ([ — [...( — (..] — ]) — ))
#
#                      whole_sequence  helix_1_bps  helix_2_bps  helix_3_bps  \
# 125959  CG — UAAAG — CUAA — CG — CG            1            1            1
# 94332   CG — UAAAG — CUAA — CG — CG            1            1            1
# ...

# %%
show_structure(indices=125959, web=True, pdf=True)
# Out:
# Structure pdf file: rnaloops/data_getter/data_pdfs/125000-126000/5-way_junction-4u1v-125959.pdf
# Structure web url: https://rnaloops.cs.put.poznan.pl/search/details/125959
#        loop_type home_structure                  db_notation  \
# 125959    05-way           4u1v  ([ — [...( — (..] — ]) — ))
#
#                      whole_sequence helix_1_bps helix_2_bps helix_3_bps  \
# 125959  CG — UAAAG — CUAA — CG — CG           1           1           1
#
#        helix_4_bps helix_5_bps helix_6_bps helix_7_bps helix_8_bps  \
# 125959           1           1          -1          -1          -1
#
#        helix_9_bps helix_10_bps helix_11_bps helix_12_bps helix_13_bps  \
# 125959          -1           -1           -1           -1           -1
#
#        helix_14_bps strand_1_nts strand_2_nts strand_3_nts strand_4_nts  \
# 125959           -1            0            3            2            0
#
#        strand_5_nts strand_6_nts strand_7_nts strand_8_nts strand_9_nts  \
# ...

# %%
show_structure(web=True)
# Out:
# Structure web url: https://rnaloops.cs.put.poznan.pl/search/details/111114
#        loop_type home_structure                            db_notation  \
# 111114    03-way           5j5b  ((((....(((( — )))).(((( — ))))..))))
#
#                                whole_sequence helix_1_bps helix_2_bps  \
# 111114  CGCCGGAAGACC — GGUCAGGUA — UACCAAGGCG           4           4
#
#        helix_3_bps helix_4_bps helix_5_bps helix_6_bps helix_7_bps  \
# 111114           4          -1          -1          -1          -1
#
#        helix_8_bps helix_9_bps helix_10_bps helix_11_bps helix_12_bps  \
# 111114          -1          -1           -1           -1           -1
#
#        helix_13_bps helix_14_bps strand_1_nts strand_2_nts strand_3_nts  \
# 111114           -1           -1            4            1            2
#
#        strand_4_nts strand_5_nts strand_6_nts strand_7_nts strand_8_nts  \
# 111114           -1           -1           -1           -1           -1
#
# ...
