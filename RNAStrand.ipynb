# %% [markdown]
# # Connecting to RNAStrand Database

# %%
from rnaloops.data_explorer.import_helper import *
rnaloops = get_prepared_df()
# Out:
# imported pandas, numpy, seaborn, matplotlib and all functions from data_explorer/explore_fcts.py

# %% [markdown]
# ### Some helper functions:

# %%
def get_con(user='root', pwd=''):
    """Call this to connect to the db after creating it on local mysql
       Follow instructions in README of RNAStrands data to set up that mysql db
    
    """
    sqlEngine = create_engine(
        f"mysql+pymysql://{user}:{pwd}@localhost/sstrand_2_0", pool_recycle=3600
    )
    
    return sqlEngine.connect()

def populate_rnaloops(tableName = "RNALoops"):
    """Call this once to create a table with RNALoops data in RNAStrands db
    
    """
    df = get_prepared_df()
    con = get_con()
    
    try:
        frame = df.to_sql(tableName, con, if_exists="fail")
    except ValueError as vx:
        print(vx)
    except Exception as ex:
        print(ex)
    else:
        print("Table %s created successfully." % tableName)
    finally:
        con.close()

# %% [markdown]
# ### Query the databases:

# %%
# Query to get matching home_structures from PDB:
def query_all(left_or_right = 'RIGHT'):
    pdb_id = 'EXTERNAL_ID' if left_or_right == 'RIGHT' else 'home_structure'
    return f"""
        SELECT {pdb_id},
        CASE WHEN a.c1 is NULL THEN 0 ELSE a.c1 END,
        CASE WHEN b.c2 is NULL THEN 0 ELSE b.c2 END
        FROM (SELECT home_structure, count(*) c1
               FROM RNALoops
               GROUP BY home_structure) a
        {left_or_right} JOIN (
        SELECT EXTERNAL_ID, count(*) c2 FROM EXTERNAL_AND_MULTI_LOOP
        JOIN MOLECULE ON 
        MOLECULE.MOLECULE_ID = EXTERNAL_AND_MULTI_LOOP.MOLECULE_ID
        WHERE TYPE = 'multi'
        GROUP BY EXTERNAL_ID) b

        ON a.home_structure = b.EXTERNAL_ID
    """

# Query to get RNAStrands multiloops for given pdb id:
def query_pdbid(pdb_id='2J28'):
    return  f"""
        SELECT * 
        FROM EXTERNAL_AND_MULTI_LOOP
        JOIN MOLECULE ON 
        MOLECULE.MOLECULE_ID = EXTERNAL_AND_MULTI_LOOP.MOLECULE_ID
        WHERE TYPE = 'multi' AND EXTERNAL_ID = '{pdb_id}'
    """

# %%
# Run the query to get matches of multiloop pdb ids in both databases:
con = get_con(pwd='2357')
left = [x for x in con.execute(query_all('LEFT'))]
right = [x for x in con.execute(query_all('RIGHT'))]
cols = 'pdb_id', '# RNALoops Multiloops', '# RNAStrands Multiloops'
result = pd.DataFrame(left + right, columns=cols)
result['difference'] = (result['# RNALoops Multiloops'] 
                        - result['# RNAStrands Multiloops'])

# %% [markdown]
# ### PDB entries found in both databases:

# %%
result.pdb_id = [x.lower() for x in result.pdb_id]
result = result.drop_duplicates()
result = result.sort_values(by=['# RNAStrands Multiloops', 
                                '# RNALoops Multiloops'], ascending=False)
result.to_csv('RNALoops_RNAStrands_compare.csv')

# %% [markdown]
# ### Example of 2j28 with 52 (16) multiloops in RNALoops (RNAStrands)

# %%
# Get an example of multiloop structures for given pdb_id:
loops = rnaloops[rnaloops.home_structure == '2j28']
strands = pd.DataFrame([x for x in con.execute(query_pdbid('2j28'))])

# %%
loops.head(2)
# Out:
#       loop_type home_structure  \
# 89715    06-way           2j28
# 89723    07-way           2j28
#
#                                              db_notation  \
# 89715  (((( — ))...( — ).........(( — ))...((((( — ))...
# 89723      (..[ — [......) — (] — ].[ — [) — (..] — ]..)
#
#                                           whole_sequence  helix_1_bps  \
# 89715  AGGC — GCGAAC — GGAAAAGAAAUC — GAGAUUCCCC — GG...            2
# 89723      ACAC — CGUGGUAU — GG — GAC — UC — UGAA — GAAG            1
#
#        helix_2_bps  helix_3_bps  helix_4_bps  helix_5_bps  helix_6_bps  \
# 89715            2            1            2            5            3
# 89723            1            1            1            1            1
#
#        helix_7_bps  helix_8_bps  helix_9_bps  helix_10_bps  helix_11_bps  \
# 89715           -1           -1           -1            -1            -1
# 89723            1           -1           -1            -1            -1
#
#        helix_12_bps  helix_13_bps  helix_14_bps  strand_1_nts  strand_2_nts  \
# 89715            -1            -1            -1             0             3
# 89723            -1            -1            -1             2             6
#
#        strand_3_nts  strand_4_nts  strand_5_nts  strand_6_nts  strand_7_nts  \
# 89715             9             3             3             6            -1
# 89723             0             1             0             2             2
#
#        strand_8_nts  strand_9_nts  strand_10_nts  strand_11_nts  \
# 89715            -1            -1             -1             -1
# 89723            -1            -1             -1             -1
#
#        strand_12_nts  strand_13_nts  strand_14_nts  end_1  end_2  end_3  \
# 89715             -1             -1             -1      -  B-182  B-223
# 89723             -1             -1             -1  B-384  B-391      -
#
#        end_4  end_5   end_6   end_7 end_8 end_9 end_10 end_11 end_12 end_13  \
# 89715  B-234  B-265   B-432    <NA>  <NA>  <NA>   <NA>   <NA>   <NA>   <NA>
# 89723  B-412      -  B-2406  B-2412  <NA>  <NA>   <NA>   <NA>   <NA>   <NA>
#
#       end_14  euler_x_1  euler_x_2   euler_x_3  euler_x_4   euler_x_5  \
# 89715   <NA>  56.109001     17.886  174.613007  43.282001  124.092003
# 89723   <NA>  38.804001      0.000  167.119995  16.518000    3.821000
#
#         euler_x_6   euler_x_7  euler_x_8  euler_x_9  euler_x_10  euler_x_11  \
# 89715  142.800003         NaN        NaN        NaN         NaN         NaN
# 89723  101.172997  117.814003        NaN        NaN         NaN         NaN
#
#        euler_x_12  euler_x_13  euler_x_14 start_1 start_2 start_3 start_4  \
# 89715         NaN         NaN         NaN       -   B-180   B-215   B-232
# 89723         NaN         NaN         NaN   B-383   B-386       -   B-412
#
#       start_5 start_6 start_7 start_8 start_9 start_10 start_11 start_12  \
# 89715   B-263   B-427    <NA>    <NA>    <NA>     <NA>     <NA>     <NA>
# 89723       -  B-2405  B-2411    <NA>    <NA>     <NA>     <NA>     <NA>
#
#       start_13 start_14  euler_y_1  euler_y_2   euler_y_3  euler_y_4  \
# 89715     <NA>     <NA>  57.426998  66.338997  142.007004  67.566002
# 89723     <NA>     <NA>  56.804001   0.000000  118.328003  91.008003
#
#         euler_y_5   euler_y_6  euler_y_7  euler_y_8  euler_y_9  euler_y_10  \
# 89715  132.080994  144.565994        NaN        NaN        NaN         NaN
# 89723   68.995003  133.824997    142.638        NaN        NaN         NaN
#
#        euler_y_11  euler_y_12  euler_y_13  euler_y_14  euler_z_1  euler_z_2  \
# 89715         NaN         NaN         NaN         NaN  37.421001     15.283
# 89723         NaN         NaN         NaN         NaN   5.346000      0.000
#
#         euler_z_3  euler_z_4  euler_z_5   euler_z_6   euler_z_7  euler_z_8  \
# 89715  146.537003  19.155001  50.063000  168.332993         NaN        NaN
# 89723  129.733002  80.392998  59.491001   62.287998  141.729996        NaN
#
#        euler_z_9  euler_z_10  euler_z_11  euler_z_12  euler_z_13  euler_z_14  \
# 89715        NaN         NaN         NaN         NaN         NaN         NaN
# 89723        NaN         NaN         NaN         NaN         NaN         NaN
#
#         planar_1  planar_2    planar_3   planar_4    planar_5    planar_6  \
# 89715  52.098999    22.768  146.160004  44.744999  111.863998  141.563995
# 89723  34.278999     0.000  137.457993  73.074997   56.724998   96.958000
#
#          planar_7  planar_8  planar_9  planar_10  planar_11  planar_12  \
# 89715         NaN       NaN       NaN        NaN        NaN        NaN
# 89723  127.535004       NaN       NaN        NaN        NaN        NaN
#
#        planar_13  planar_14 sequence_1 sequence_2 sequence_3 sequence_4  \
# 89715        NaN        NaN      AG-CU                 GC-GC        GAA
# 89723        NaN        NaN        A-U         CA        C-G     GUGGUA
#
#       sequence_5 sequence_6 sequence_7 sequence_8   sequence_9 sequence_10  \
# 89715        C-G  GAAAAGAAA      UC-GA        GAU  UCCCC-GGGGA         GCA
# 89723        C-G                   G-C          A          C-G
#
#       sequence_11 sequence_12 sequence_13 sequence_14 sequence_15 sequence_16  \
# 89715     GCC-GGC      UAAAUA        <NA>        <NA>        <NA>        <NA>
# 89723         U-A          GA         U-G          AA        <NA>        <NA>
#
#       sequence_17 sequence_18 sequence_19 sequence_20 sequence_21 sequence_22  \
# 89715        <NA>        <NA>        <NA>        <NA>        <NA>        <NA>
# 89723        <NA>        <NA>        <NA>        <NA>        <NA>        <NA>
#
#       sequence_23 sequence_24 sequence_25 sequence_26 sequence_27 sequence_28
# 89715        <NA>        <NA>        <NA>        <NA>        <NA>        <NA>
# 89723        <NA>        <NA>        <NA>        <NA>        <NA>        <NA>

# %%
strands.head(2)
# Out:
#    EXT_MULTI_ID MOLECULE_ID   TYPE  NUM_BRANCHES  TOTAL_NUM_FREE_BASES  \
# 0          3184   PDB_01143  MULTI             4                    10
# 1          3185   PDB_01143  MULTI             3                    11
#
#    5P_COORDINATE  3P_COORDINATE  LEN_5P_END  ASYM_AD_MAX  ASYM_AD_MIN  \
# 0            199           3024           6          6.0          0.0
# 1           2941           3017           2          3.0          1.0
#
#    ASYM_AD_AVG  ASYM_RA_MAX  ASYM_RA_MIN  ASYM_RA_AVG MOLECULE_ID  \
# 0          3.0          3.0          0.0         0.96   PDB_01143
# 1          2.0          2.5          0.4         1.24   PDB_01143
#
#       SUBMITTER_NAME     SUBMITTER_EMAIL SUBMISSION_DATE_TIME  \
# 0  Mirela Andronescu  andrones@cs.ubc.ca  2022-10-13 14:06:38
# 1  Mirela Andronescu  andrones@cs.ubc.ca  2022-10-13 14:06:38
#
#                              MOLECULE_NAME  RNA_TYPE_ID          ORGANISM  \
# 0  MODEL OF E. COLI SRP BOUND TO 70S RNCS            10  ESCHERICHIA COLI
# 1  MODEL OF E. COLI SRP BOUND TO 70S RNCS            10  ESCHERICHIA COLI
#
#    EXTERNAL_SOURCE_ID EXTERNAL_ID  \
# 0                   2        2J28
# 1                   2        2J28
#
#                                     EXTERNAL_ID_LINK  \
# 0  http://www.rcsb.org/pdb/explore/explore.do?str...
# 1  http://www.rcsb.org/pdb/explore/explore.do?str...
#
#                                             SEQUENCE  \
# 0  UCUGUGCUCUGUGCUCUGUUUACCAGGUCAGGUCCGAAAGGAAGCA...
# 1  UCUGUGCUCUGUGCUCUGUUUACCAGGUCAGGUCCGAAAGGAAGCA...
#
#                                     ABSTRACT_SHAPE_1  \
# 0  [[[_[_[]_]_]_]_][_[[_[[]_]_]_][_[]_]_][_[_[[_[...
# 1  [[[_[_[]_]_]_]_][_[[_[[]_]_]_][_[]_]_][_[_[[_[...
#
#                                     ABSTRACT_SHAPE_3  \
# 0  [[[[[]]]]][[[[[]]]][[]]][[[[[[[[[[][[]]][][][]...
# 1  [[[[[]]]]][[[[[]]]][[]]][[[[[[[[[[][[]]][][][]...
#
#                                     ABSTRACT_SHAPE_5  \
# 0  [][[][]][[[[[[[][]][][][]][][[][][[[][]][][]]]...
# 1  [][[][]][[[[[[[][]][][][]][][[][][[[][]][][]]]...
#
#                                            REFERENCE EXPERIMENTALLY_PROVEN  \
# 0  M.HALIC,M.BLAU,T.BECKER,T.MIELKE,M.R.POOL,K.WI...                     Y
# 1  M.HALIC,M.BLAU,T.BECKER,T.MIELKE,M.R.POOL,K.WI...                     Y
#
#                                               METHOD  NUM_MOLECULES FRAGMENT  \
# 0  X-RAY, RESOLUTION 8.00 ANGSTROMS; ran through ...              3        N
# 1  X-RAY, RESOLUTION 8.00 ANGSTROMS; ran through ...              3        N
#
#   COMMENTS VISIBLE LINK_IF_NOT_VISIBLE     VALIDATOR_NAME  \
# 0     None       Y                None  Mirela Andronescu
# 1     None       Y                None  Mirela Andronescu
#
#   VALIDATION_DATE_TIME       CT_FILE  LENGTH  TOTAL_NUM_ARCS_TO_REMOVE  \
# 0  2022-10-13 14:06:38  PDB_01143.ct    3032                        25
# 1  2022-10-13 14:06:38  PDB_01143.ct    3032                        25
#
#    TOTAL_NUM_BANDS_TO_REMOVE TOTAL_UNIQUE_REMOVE  NUM_DOMAINS  NUM_STEMS  \
# 0                          9                   Y            3        149
# 1                          9                   Y            3        149
#
#    NUM_BASE_PAIRS_IN_STEMS  NUM_HAIRPIN_LOOPS  NUM_BULGES  NUM_INTERNAL_LOOPS  \
# 0                      787                 59          42                  31
# 1                      787                 59          42                  31
#
#    NUM_MULTI_LOOPS  NUM_PSEUDOKNOTS  NUM_BANDS  NUM_BASE_PAIRS_IN_BANDS  \
# 0               16                6         22                      235
# 1               16                6         22                      235
#
#    LEN_STEM_MAX  LEN_STEM_MIN  LEN_STEM_AVG  LEN_HAIRPIN_MAX  LEN_HAIRPIN_MIN  \
# 0          13.0           2.0          5.29             13.0              1.0
# 1          13.0           2.0          5.29             13.0              1.0
#
#    LEN_HAIRPIN_AVG  LEN_BULGE_MAX  LEN_BULGE_MIN  LEN_BULGE_AVG  \
# 0             4.66            3.0            0.0           0.74
# 1             4.66            3.0            0.0           0.74
#
#    LEN_INT_LOOP_MAX  LEN_INT_LOOP_MIN  LEN_INT_LOOP_AVG  LEN_MULTI_LOOP_MAX  \
# 0               5.0               1.0              1.94                20.0
# 1               5.0               1.0              1.94                20.0
#
#    LEN_MULTI_LOOP_MIN  LEN_MULTI_LOOP_AVG  LEN_BAND_MAX  LEN_BAND_MIN  \
# 0                 0.0                3.13          39.0           2.0
# 1                 0.0                3.13          39.0           2.0
#
#    LEN_BAND_AVG
# 0         10.68
# 1         10.68
